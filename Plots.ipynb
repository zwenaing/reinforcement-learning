# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Number of Time Steps to reach the Goal

# %% [markdown]
# ## Q Learning

# %% [markdown]
# ### Different Alpha Values

# %%
steps = np.load("HW4/generated_data/alpha0.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.0, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.0, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/alpha001.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.01, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.01, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/alpha005.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.05, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.05, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/alpha01.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/alpha05.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.5, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.5, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/alpha1.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 1.0, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Gamma 0.99, Epsilon 0.1')

# %% [markdown]
# ### Different Epsilon Values

# %%
steps = np.load("HW4/generated_data/epsilon01.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/epsilon025.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.25")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.25')

# %%
steps = np.load("HW4/generated_data/epsilon05.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.5')

# %%
steps = np.load("HW4/generated_data/epsilon1.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 1.0")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 1.0')

# %% [markdown]
# ## Sarsa Learning

# %% [markdown]
# ### Different Alpha Values

# %%
steps = np.load("HW4/generated_data/sarsa_learning/alpha001.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.01, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.01, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/alpha005.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.05, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.05, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/alpha01.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/alpha05.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.5, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.5, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/alpha1.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 1.0, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Gamma 0.99, Epsilon 0.1')

# %% [markdown]
# ### Different Epsilon Values

# %%
steps = np.load("HW4/generated_data/sarsa_learning/epsilon01.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/epsilon025.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.25")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.25')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/epsilon05.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.5')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/epsilon1.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 1.0")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 1.0')

# %% [markdown]
# ### Different Lambda Values

# %%
steps = np.load("HW4/generated_data/sarsa_learning/lambda0.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 0.0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/lambda025.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 0.25, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.25, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/lambda05.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 0.50, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.50, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/lambda075.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 0.75, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.75, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/sarsa_learning/lambda1.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 1.0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 1.0, Epsilon 0.1')

# %% [markdown]
# # Q Values of the Beginning State

# %% [markdown]
# ## Q Learning

# %% [markdown]
# ### Different Alpha Values

# %%
steps = np.load("HW4/generated_data/q_learning_startq/alpha001.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/alpha005.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/alpha01.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/alpha05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/alpha1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %% [markdown]
# ### Different Epsilon Values

# %%
steps = np.load("HW4/generated_data/q_learning_startq/epsilon01.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/epsilon025.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.25")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.25')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/epsilon05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 0.5')

# %%
steps = np.load("HW4/generated_data/q_learning_startq/epsilon1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Gamma 0.99, Epsilon 1.0")
# Out:
# Text(0.5,1,'Alpha 0.1, Gamma 0.99, Epsilon 1.0')

# %% [markdown]
# ## Sarsa Lambda Learning

# %% [markdown]
# ### Different Alpha Values

# %%
steps = np.load("HW4/generated_data/s_learning_startq/alpha001.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.01, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.01, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/alpha005.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.05, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.05, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/alpha01.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/alpha05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.5, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.5, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/alpha1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 0.1')

# %% [markdown]
# ### Different Epsilon Values

# %%
steps = np.load("HW4/generated_data/s_learning_startq/epsilon01.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/epsilon025.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 0.25")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 0.25')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/epsilon05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 0.5')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/epsilon1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 1.0")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 1.0')

# %%
steps = np.load("HW4/generated_data/s1/epsilon01.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/epsilon025.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 0.25")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 0.25')

# %%
steps = np.load("HW4/generated_data/s1/epsilon05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 0.5')

# %%
steps = np.load("HW4/generated_data/s1/epsilon1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 1.0")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 1.0')

# %% [markdown]
# ### Different Lambda Values

# %%
steps = np.load("HW4/generated_data/s_learning_startq/lambda0.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/lambda025.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0.25, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.25, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/lambda05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0.5, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.5, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/lambda075.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 0.75, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.75, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s_learning_startq/lambda1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 0.1, Lambda 1.0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 1.0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/lambda0.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/lambda025.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0.25, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0.25, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/lambda05.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0.5, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0.5, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/lambda075.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 0.75, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0.75, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s1/lambda1.npy")
plt.plot(np.arange(500), steps)
plt.xlabel("Number of Episodes")
plt.ylabel("Q values of beginning state")
plt.title("Alpha 1.0, Lambda 1.0, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 1.0, Epsilon 0.1')

# %% [markdown]
# ## 10 x 10 Grid Q Learning

# %%
steps = np.load("HW4/generated_data/q10x10.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 1.0, Gamma 0.99, Epsilon 0.5")
# Out:
# Text(0.5,1,'Alpha 1.0, Gamma 0.99, Epsilon 0.5')

# %% [markdown]
# ## 10 x 10 Grid Sarsa Learning

# %%
steps = np.load("HW4/generated_data/s10x10.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 0.1, Lambda 0.5, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 0.1, Lambda 0.5, Epsilon 0.1')

# %%
steps = np.load("HW4/generated_data/s10x10.npy")
plt.plot(np.arange(500), steps)
plt.yscale('log')
plt.xlabel("Number of Episodes")
plt.ylabel("Time steps to reach the goal")
plt.title("Alpha 1.0, Lambda 0.5, Epsilon 0.1")
# Out:
# Text(0.5,1,'Alpha 1.0, Lambda 0.5, Epsilon 0.1')
